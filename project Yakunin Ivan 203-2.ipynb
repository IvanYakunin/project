# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dt = pd.read_csv('C:\\Users\\mi\\Downloads\\BankChurners.csv')

# %%
dt = pd.DataFrame(dt)
dt.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
# №1

# %%
dt['Credit_Limit'].median()
# Out:
# 4549.0

# %%
dt['Credit_Limit'].mean()
# Out:
# 8631.953698034955

# %%
dt['Credit_Limit'].std()
# Out:
# 9088.776650223155

# %%
dt['Customer_Age'].median()
# Out:
# 46.0

# %%
dt['Customer_Age'].mean()
# Out:
# 46.32596030413745

# %%
dt['Customer_Age'].std()
# Out:
# 8.016814032549028

# %%
dt['Gender'].value_counts()
# Out:
# F    5358
# M    4769
# Name: Gender, dtype: int64

# %%
# №2

# %%
# What education level do the owners of credit cards have?

# %%
sns.countplot(y = 'Education_Level', data = dt)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Education_Level'>

# %%
# What card's status do owners have?

# %%
sns.displot(dt.Card_Category)

# %%
# What marital status do owners have?

# %%
sns.countplot(y = 'Marital_Status', data = dt)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Marital_Status'>

# %%
# №3

# %%
# How does the age of a cutomer depends on their credit limit?

# %%
sns.lineplot(x = 'Customer_Age', y = 'Credit_Limit', data = dt)
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Credit_Limit'>

# %%
# Does the direct correlation between months on book and credit limit exists?

# %%
sns.lineplot(x = 'Months_on_book', y = 'Credit_Limit', data = dt)
# Out:
# <AxesSubplot:xlabel='Months_on_book', ylabel='Credit_Limit'>

# %%
g = sns.catplot(data = dt, kind="violin", x = 'Education_Level', y = 'Total_Revolving_Bal', hue = 'Gender', split=True)
g.fig.set_size_inches(15,15)

# %%
# №4

# %% [markdown]
# By summarizing yhe information about one can calim that, thirstly, graduates are the most part of banks clients.
# Secondly, practically all owners of credit cards use the most simpliest class of credit cards. Thierdly, the majority of clients obviously are either married or single.
#
# From all the comparisons above it may be said the credit limit is significantly influenced by a clint's age(people in the age from 40 to 50 have the biggest ones). Moreover, despite all preceptions, the longer contact with a bank does not influence one's credit limit(People, cooperate with a bank for 50+ month, have smaller credit limit in comparison with ones, who cooperate for 40-50 months)
#
# Additionally, the last chart states that men and women spend approximately the same amount of money
